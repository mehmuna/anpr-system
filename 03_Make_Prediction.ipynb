# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import load_img,img_to_array

# %%
#load model
model=tf.keras.models.load_model(r'MODEL\object_detection.h5')
print('model loaded sucessfully')
# Out:
# model loaded sucessfully

# %%
path=r'D:\ANPR_SYSTEM1\test_images\Cars0.png'
image=load_img(path) #PIL obj
image=np.array(image,dtype=np.uint8)  #8 bit array (0,255)
image1=load_img(path,target_size=(224,224))
image_arr_224=img_to_array(image1)/255.0   #convert into array and get normalized o/p

# %%
#size of the original image
h,w,d=image.shape
print('height of the image=',h)
print('width of the image=',w)
# Out:
# height of the image= 268
# width of the image= 500

# %%
plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()

# %%
image_arr_224.shape
# Out:
# (224, 224, 3)

# %%
test_arr=image_arr_224.reshape(1,224,224,3)
test_arr.shape
# Out:
# (1, 224, 224, 3)

# %%
#make prediction
coords=model.predict(test_arr)
coords
#give normalized o/p
# Out:
# 1/1 [==============================] - 10s 10s/step
# array([[0.44694903, 0.8316206 , 0.46813402, 0.61438966]], dtype=float32)

# %%
#denormalized the values
denorm=np.array([w,w,h,h])
coords=coords*denorm
coords
# Out:
# array([[223.47451746, 415.810287  , 125.45991623, 164.65642834]])

# %%
coords=coords.astype(np.int32)
coords
#converting from float to int
# Out:
# array([[223, 415, 125, 164]])

# %%
#drawing bounding box on top of the image
xmin,xmax,ymin,ymax=coords[0]
pt1=(xmin,ymin)
pt2=(xmax,ymax)
print(pt1,pt2)
cv2.rectangle(image,pt1,pt2,(0,225,0),2)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# (223, 125) (415, 164)

# %%
path=r'D:\ANPR_SYSTEM1\test_images\Cars1.png'
image=load_img(path) #PIL obj
image=np.array(image,dtype=np.uint8)  #8 bit array (0,255)
image2=load_img(path,target_size=(224,224))
image_arr_224=img_to_array(image2)/255.0   #convert into array and get normalized o/p

# %%
#size of the original image
h,w,d=image.shape
print('height of the image=',h)
print('width of the image=',w)
# Out:
# height of the image= 248
# width of the image= 400

# %%
plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()

# %%
image_arr_224.shape
# Out:
# (224, 224, 3)

# %%
test_arr=image_arr_224.reshape(1,224,224,3)
test_arr.shape
# Out:
# (1, 224, 224, 3)

# %%
#make prediction
coords=model.predict(test_arr)
coords
#give normalized o/p
# Out:
# 1/1 [==============================] - 0s 291ms/step
# array([[0.3381055 , 0.65331185, 0.49885282, 0.636868  ]], dtype=float32)

# %%
#denormalized the values
denorm=np.array([w,w,h,h])
coords=coords*denorm
coords
# Out:
# array([[135.2421999 , 261.32473946, 123.71549916, 157.94326401]])

# %%
coords=coords.astype(np.int32)
coords
#converting from float to int
# Out:
# array([[135, 261, 123, 157]])

# %%
#drawing bounding box on top of the image
xmin,xmax,ymin,ymax=coords[0]
pt1=(xmin,ymin)
pt2=(xmax,ymax)
print(pt1,pt2)
cv2.rectangle(image,pt1,pt2,(0,225,0),2)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# (135, 123) (261, 157)

# %%
path=r'D:\ANPR_SYSTEM1\test_images\Cars3.png'
image=load_img(path) #PIL obj
image=np.array(image,dtype=np.uint8)  #8 bit array (0,255)
image2=load_img(path,target_size=(224,224))
image_arr_224=img_to_array(image2)/255.0   #convert into array and get normalized o/p

# %%
#size of the original image
h,w,d=image.shape
print('height of the image=',h)
print('width of the image=',w)
# Out:
# height of the image= 225
# width of the image= 400

# %%
plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()

# %%
image_arr_224.shape
# Out:
# (224, 224, 3)

# %%
test_arr=image_arr_224.reshape(1,224,224,3)
test_arr.shape
# Out:
# (1, 224, 224, 3)

# %%
#make prediction
coords=model.predict(test_arr)
coords
#give normalized o/p
# Out:
# 1/1 [==============================] - 0s 295ms/step
# array([[0.3534168 , 0.62620395, 0.56932044, 0.69304365]], dtype=float32)

# %%
#denormalized the values
denorm=np.array([w,w,h,h])
coords=coords*denorm
coords
# Out:
# array([[141.3667202 , 250.48158169, 128.09709907, 155.93482107]])

# %%
coords=coords.astype(np.int32)
coords
#converting from float to int
# Out:
# array([[141, 250, 128, 155]])

# %%
#drawing bounding box on top of the image
xmin,xmax,ymin,ymax=coords[0]
pt1=(xmin,ymin)
pt2=(xmax,ymax)
print(pt1,pt2)
cv2.rectangle(image,pt1,pt2,(0,225,0),2)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# (141, 128) (250, 155)

# %%
path=r'D:\ANPR_SYSTEM1\test_images\Cars4.png'
image=load_img(path) #PIL obj
image=np.array(image,dtype=np.uint8)  #8 bit array (0,255)
image2=load_img(path,target_size=(224,224))
image_arr_224=img_to_array(image2)/255.0   #convert into array and get normalized o/p

# %%
#size of the original image
h,w,d=image.shape
print('height of the image=',h)
print('width of the image=',w)
# Out:
# height of the image= 350
# width of the image= 590

# %%
plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()

# %%
image_arr_224.shape
# Out:
# (224, 224, 3)

# %%
test_arr=image_arr_224.reshape(1,224,224,3)
test_arr.shape
# Out:
# (1, 224, 224, 3)

# %%
#make prediction
coords=model.predict(test_arr)
coords
#give normalized o/p
# Out:
# 1/1 [==============================] - 0s 275ms/step
# array([[0.20536564, 0.8748573 , 0.20730522, 0.69691694]], dtype=float32)

# %%
#denormalized the values
denorm=np.array([w,w,h,h])
coords=coords*denorm
coords
# Out:
# array([[121.16572931, 516.16581082,  72.55682796, 243.92092824]])

# %%
coords=coords.astype(np.int32)
coords
#converting from float to int
# Out:
# array([[121, 516,  72, 243]])

# %%
#drawing bounding box on top of the image
xmin,xmax,ymin,ymax=coords[0]
pt1=(xmin,ymin)
pt2=(xmax,ymax)
print(pt1,pt2)
cv2.rectangle(image,pt1,pt2,(0,225,0),2)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# (121, 72) (516, 243)

# %%
path=r'D:\ANPR_SYSTEM1\test_images\Cars0.png'
def object_detection(path):
        #read image
        image=load_img(path) #PIL obj
        image=np.array(image,dtype=np.uint8)  #8 bit array (0,255)
        image1=load_img(path,target_size=(224,224))
        image_arr_224=img_to_array(image1)/255.0   #convert into array and get normalized o/p
        h,w,d=image.shape
        test_arr=image_arr_224.reshape(1,224,224,3)
      
        #make prediction
        coords=model.predict(test_arr)
        #denormalized the values
        denorm=np.array([w,w,h,h])
        coords=coords*denorm
        #converting from float to int
        coords=coords.astype(np.int32)
        #drawing bounding box on top of the image
        xmin,xmax,ymin,ymax=coords[0]
        pt1=(xmin,ymin)
        pt2=(xmax,ymax)
        print(pt1,pt2)
        cv2.rectangle(image,pt1,pt2,(0,225,0),3)
        return image,coords

# %%
path=r'D:\ANPR_SYSTEM1\test_images\Cars0.png'
image, coords = object_detection(path)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# 1/1 [==============================] - 0s 292ms/step
# (223, 125) (415, 164)

# %%
path=r'D:\ANPR_SYSTEM1\test_images\Cars7.png'
image, coords = object_detection(path)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# 1/1 [==============================] - 0s 300ms/step
# (160, 141) (207, 152)

# %% [markdown]
# # OCR

# %%
import pytesseract as pt

# %%
path=r'D:\ANPR_SYSTEM1\test_images\Cars0.png'
image, coords = object_detection(path)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# 1/1 [==============================] - 0s 307ms/step
# (223, 125) (415, 164)

# %%
img=np.array(load_img(path))
img
# Out:
# array([[[ 25,  75, 100],
#         [ 73, 130, 159],
#         [ 52, 127, 158],
#         ...,
#         [ 38,  39,  41],
#         [ 33,  34,  36],
#         [ 37,  38,  40]],
#
#        [[ 31,  79, 101],
#         [ 65, 121, 146],
#         [ 46, 119, 151],
#         ...,
#         [ 31,  33,  32],
#         [ 41,  43,  42],
#         [ 26,  28,  27]],
#
#        [[ 44,  87, 104],
#         [ 65, 117, 139],
#         [ 43, 116, 146],
#         ...,
#         [ 32,  37,  33],
#         [ 35,  40,  36],
#         [ 25,  30,  26]],
#
#        ...,
#
#        [[ 72,  49,  41],
#         [ 73,  50,  42],
#         [ 74,  51,  43],
#         ...,
#         [104,  67,  48],
#         [103,  68,  48],
#         [104,  67,  48]],
#
#        [[ 75,  52,  44],
#         [ 76,  53,  45],
#         [ 75,  52,  44],
#         ...,
#         [104,  66,  47],
#         [104,  67,  48],
#         [105,  67,  48]],
#
#        [[ 75,  52,  44],
#         [ 75,  52,  44],
#         [ 75,  52,  44],
# ...

# %%
img=np.array(load_img(path))
xmin,xmax,ymin,ymax=coords[0]
roi=img[ymin:ymax,xmin:xmax]

# %%
plt.imshow(roi)
plt.show()

# %%
#extract text from image
text=pt.image_to_string(roi)
print(text)
# Out:
# yi CA2555

# %%
pip install tesseract
# Out:
# ...
#   Created wheel for tesseract: filename=tesseract-0.1.3-py3-none-any.whl size=45562571 sha256=2c00b7f35b88e776422b2b956283226f70cf8f206411a84df5246eff04b0a5bb
#   Stored in directory: c:\users\mubashir khan\appdata\local\pip\cache\wheels\6c\c5\81\8310cc52076953e53412ed1875a5e224c92940235bdcee21a2
# Successfully built tesseract
# ...
# Note: you may need to restart the kernel to use updated packages.
